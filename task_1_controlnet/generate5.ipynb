# %%
# !nvidia-smi
# Out:
# Thu Jun 19 20:53:16 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L40S                    On  |   00000000:2A:00.0 Off |                    0 |
# | N/A   33C    P8             33W /  350W |       1MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA L40S                    On  |   00000000:99:00.0 Off |                    0 |
# | N/A   31C    P8             31W /  350W |       1MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA L40S                    On  |   00000000:AB:00.0 Off |                    0 |
# | N/A   32C    P8             32W /  350W |       1MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !conda env list
# Out:
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/usr/local/anaconda3-2023/lib/python3.11/site-packages/conda/plugins/types.py))
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/usr/local/anaconda3-2023/lib/python3.11/site-packages/conda/plugins/types.py))
# WARNING conda.plugins.manager:load_entrypoints(114): Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/usr/local/anaconda3-2023/lib/python3.11/site-packages/conda/plugins/types.py))
# WARNING conda.plugins.manager:load_entrypoints(114): Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/usr/local/anaconda3-2023/lib/python3.11/site-packages/conda/plugins/types.py))
# # conda environments:
# #
# ddpm                     /home/minhthan001/.conda/envs/ddpm
# myenv2                *  /home/minhthan001/.conda/envs/myenv2
# nano                     /home/minhthan001/.conda/envs/nano
# ola                      /home/minhthan001/.conda/envs/ola
# worldsense               /home/minhthan001/.conda/envs/worldsense
# base                     /usr/local/anaconda3-2023
# adios2                   /usr/local/anaconda3-2023/envs/adios2
# cafe                     /usr/local/anaconda3-2023/envs/cafe
# coudalfish               /usr/local/anaconda3-2023/envs/coudalfish
# fenicsproject            /usr/local/anaconda3-2023/envs/fenicsproject
# gcc5.4.0                 /usr/local/anaconda3-2023/envs/gcc5.4.0
# gpu_enabled              /usr/local/anaconda3-2023/envs/gpu_enabled
# modulus                  /usr/local/anaconda3-2023/envs/modulus
# testedwin                /usr/local/anaconda3-2023/envs/testedwin

# %%
# %cd /home/minhthan001/Projects/controlnet_lora/task_1_controlnet
# Out:
# /home/minhthan001/Projects/controlnet_lora/task_1_controlnet

# %%
import torch
from diffusers import StableDiffusionPipeline
import json

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)

prompt_path = "data/test_prompts.json"
with open(prompt_path, "r") as f:
    prompts = json.load(f)
# Out:
# Loading pipeline components...:  71%|██████████████████████████████████████████████████▋                    | 5/7 [00:00<00:00,  8.29it/s]/home/minhthan001/.conda/envs/myenv2/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loading pipeline components...: 100%|███████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.42it/s]

# %%
for i, prompt in prompts.items():
    image = pipe(prompt).images[0]
    print("Run prompt")
    print(prompt)
    display(image)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:14<00:00,  3.35it/s]
# Run prompt
# pale golden rod circle with old lace background
# <PIL.Image.Image image mode=RGB size=512x512>
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 44.79it/s]
# Run prompt
# sea green circle with a light cyan background
# <PIL.Image.Image image mode=RGB size=512x512>
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 44.75it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Run prompt
# deep sky blue circle with a light yellow background
# <PIL.Image.Image image mode=RGB size=512x512>
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 44.66it/s]
# Run prompt
# rosy brown circle with a misty rose background
# <PIL.Image.Image image mode=RGB size=512x512>
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 44.69it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Run prompt
# forest green circle with an antique brown background
# <PIL.Image.Image image mode=RGB size=512x512>
